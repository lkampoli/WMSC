# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
#import matplotlib.image as mpimg

# %%
matplotlib.rc('xtick', labelsize=25) 
matplotlib.rc('ytick', labelsize=25)

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 25}

matplotlib.rc('font', **font)

# %%
# Reference data solutions 
##########################
path = '01_Data/postProcessing/sets/20059.95/'
X3D_U       = pd.read_csv(path+'X3D_U.csv')
X3D_k_Rterm = pd.read_csv(path+'X3D_k_Rterm.csv')
X3D_aij     = pd.read_csv(path+'X3D_aij.csv')

# Ali's solutions
#################
path = '03_Simulation/WMSC_BSL_kOmegaSST/postProcessing/sets/10000/'
X3D_U_Ali   = pd.read_csv(path+'X3D_U.csv')
X3D_k_Ali   = pd.read_csv(path+'X3D_k.csv')

# kOmegaSSTx
#####################
path = '03_Simulation/WMSC_BSL_kOmegaSSTx/postProcessing/sets/10000/'
X3D_U_kOmegaSSTx    = pd.read_csv(path+'X3D_U.csv')
X3D_k_Rc_kOmegaSSTx = pd.read_csv(path+'X3D_k_Rc.csv')
X3D_Ax_kOmegaSSTx   = pd.read_csv(path+'X3D_Ax.csv')

######
path = '03_Simulation/WMSC_rnd611_1e5_p100_g4_AC5_LM_l5_no10_comp_As0c79_Rs2c28/postProcessing/sets/10000/'
X3D_U_best    = pd.read_csv(path+'X3D_U.csv')
X3D_k_Rc_best = pd.read_csv(path+'X3D_k_Rc.csv')
X3D_Ax_best   = pd.read_csv(path+'X3D_Ax.csv')

path = '03_Simulation/WMSC_rnd611_1e5_p100_g4_AC5_LM_l5_no10_comp_As0c79_Rs2c28/postProcessing/sets/10000/new/'
X3D_U_best___ = pd.read_csv(path+'X3D_U.csv')
X3D_k_best___ = pd.read_csv(path+'X3D_k.csv')

######
path = '03_Simulation/smsc_rans_half_Baseline_k_omega_SST/postProcessing/sets/10000/'
X3lineX1_U = np.loadtxt(path+'X3lineX1_U.xy')
X3lineX1_k = np.loadtxt(path+'X3lineX1_k.xy')

######
path = '03_Simulation/WMSC_BSL_kOmegaSSTx_clustering/postProcessing/sets/12000/'
my_X3D_U = pd.read_csv(path+'X3D_U.csv')
my_X3D_k = pd.read_csv(path+'X3D_k.csv')

# Fabian best
path = '/home/unimelb.edu.au/lcampoli/UoM/Testcases/SquaredCylinder/03_Simulation/WMSC_rnd613_1e5_p100_g4_AC5_LM_l7_no10_comp_240h_As0c16_Rs2c63_xc/postProcessing/sets/10000/'
Fabian_X3D_U_best = pd.read_csv(path+'X3D_U.csv')
Fabian_X3D_k_best = pd.read_csv(path+'X3D_k_Rc.csv')

# just a check ...
path = '/home/unimelb.edu.au/lcampoli/UoM/Testcases/SquaredCylinder/03_Simulation/WMSC_rnd613_1e5_p100_g4_AC5_LM_l7_no10_comp_240h_As0c16_Rs2c63_xc/postProcessing/sets/10000/mine/'
Fabian_X3D_U_best__ = pd.read_csv(path+'X3D_U.csv')
Fabian_X3D_k_best__ = pd.read_csv(path+'X3D_k_Rc.csv')

# Ali best 
path = '/home/unimelb.edu.au/lcampoli/UoM/Testcases/SquaredCylinder/03_Simulation/WMSC_ALI_B_xc/postProcessing/sets/10000/'
Ali_X3D_U_best = pd.read_csv(path+'X3D_U.csv')
Ali_X3D_k_best = pd.read_csv(path+'X3D_k_Rc.csv')

# just check ...
#path = '/home/unimelb.edu.au/lcampoli/UoM/Testcases/SquaredCylinder/03_Simulation/WMSC_ALI_B_xc/postProcessing/sets/10000/originals/'
Ali_X3D_U_best__ = pd.read_csv(path+'X3D_U.csv')
Ali_X3D_k_best__ = pd.read_csv(path+'X3D_k_Rc.csv')

# from me ...
path = '03_Simulation/WMSC_rnd11_1e5_p100_g4_AC5_LM_l5_no10_comp/postProcessing/sets/10000/'
me1_X3D_U = pd.read_csv(path+'X3D_U.csv')
me1_X3D_k = pd.read_csv(path+'X3D_k.csv')

path = '03_Simulation/WMSC_rnd11_1e5_p100_g4_AC5_LM_l5_no10_comp/postProcessing/sets/10000/mine/'
me1_X3D_U__ = pd.read_csv(path+'X3D_U.csv')
me1_X3D_k__ = pd.read_csv(path+'X3D_k.csv')

path = '03_Simulation/WMSC_rnd11_1e5_p100_g4_AC5_LM_l5_no10_comp_only_Q2Q9/postProcessing/sets/9000/'
me1_X3D_U_Q2Q9 = pd.read_csv(path+'X3D_U.csv')
me1_X3D_k_Q2Q9 = pd.read_csv(path+'X3D_k.csv')

path = '03_Simulation/WMSC_rnd11_1e5_p100_g4_AC5_LM_l5_no10_comp_REGION_ABC/postProcessing/sets/10000/'
me1_X3D_U_ABC = pd.read_csv(path+'X3D_U.csv')
me1_X3D_k_ABC = pd.read_csv(path+'X3D_k.csv')

# %%
plt.figure(figsize=(20,15), frameon=False)
#
plt.plot(X3D_U['U_0'], X3D_U['z'], label='RANS/LES', linewidth=5, c='k')
plt.scatter(X3D_U_Ali['U_0'], X3D_U_Ali['z'], label='LEVM', c='r') 
plt.plot(Ali_X3D_U_best['U_0'], Ali_X3D_U_best['z'], linestyle = 'dashed',  linewidth='5', label='HAG', c='b') 
#plt.plot(Ali_X3D_U_best__['U_0'], Ali_X3D_U_best__['z'], linestyle = 'dashed',  linewidth='5', label='HAG__', c='m') 
#plt.scatter(X3lineX1_k[:,1], X3lineX1_k[:,0], label='?')
#plt.scatter(X3D_k_Rc_kOmegaSSTx['k'], X3D_k_Rc_kOmegaSSTx['z'], label='kOmegaSSTx') 
#plt.plot(X3D_U_best['U_0'], X3D_U_best['z'], label='LM-L2-MC-6-30', c='g', linestyle='dashed', linewidth='5')
plt.plot(Fabian_X3D_U_best['U_0'], Fabian_X3D_U_best['z'], label='LM-L2-MC-6-30', c='g', linestyle='dashed', linewidth='5')
#plt.plot(Fabian_X3D_U_best__['U_0'], Fabian_X3D_U_best__['z'], label='LM-L2-MC-6-30', c='m', linestyle='dashed', linewidth='5')
#plt.plot(me1_X3D_U['U_0'], me1_X3D_U['z'], linestyle = 'dashed',  linewidth='5', label='me1', c='y') 
#plt.plot(me1_X3D_U__['U_0'], me1_X3D_U__['z'], linestyle = 'dashed',  linewidth='5', label='me1', c='orange') 
#plt.plot(me1_X3D_U_Q2Q9['U_0'], me1_X3D_U_Q2Q9['z'], linestyle = 'dashed',  linewidth='5', label='me1', c='y') 
#plt.plot(X3D_U_best___['U_0'], X3D_U_best___['z'], label='check test new', c='m', linestyle='dashed', linewidth='5') # <--- strange!!!
#plt.plot(X3D_U['U_0'], X3D_U['z'], label='RANS/LES', linewidth=5, c='k')
#plt.scatter(X3D_U_Ali['U_0'], X3D_U_Ali['z'], label='LEVM')
#plt.scatter(X3D_U_kOmegaSSTx['U_0'], X3D_U_kOmegaSSTx['z'], label='kOmegaSSTx')
#plt.scatter(X3D_U_best['U_0'], X3D_U_best['z'], label='LM-L2-MC-6-30')
#plt.scatter(X3lineX1_U[:,1], X3lineX1_U[:,0], label='?')
#plt.scatter(my_X3D_U['U_0'], my_X3D_U['z'], label='mine')
#plt.plot(me1_X3D_U_ABC['U_0'], me1_X3D_U_ABC['z'], label='my ABC', c='m', linestyle='dashed', linewidth='5')
#
plt.title('Wall-normal profiles of mean streamwise velocity on centerline at x/d = 3 of NLEVM case')
plt.xlabel(r'$\bar{u}_{1}}$ / $\bar{u}_{f}}$ [-]')
plt.ylabel("$z/d$ [-]")
#
plt.grid()
plt.legend()
plt.savefig('Sc_U.png')
plt.show()
plt.close()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
plt.figure(figsize=(20,15), frameon=False)
#
plt.plot(X3D_k_Rterm['k'], X3D_k_Rterm['z'], label='RANS/LES', linewidth=5, c='k')
plt.scatter(X3D_k_Ali['k'], X3D_k_Ali['z'], label='LEVM', c='r') 
#plt.scatter(X3lineX1_k[:,1], X3lineX1_k[:,0], label='?')
#plt.scatter(X3D_k_Rc_kOmegaSSTx['k'], X3D_k_Rc_kOmegaSSTx['z'], label='kOmegaSSTx') 
#plt.plot(X3D_k_Rc_best['k'], X3D_k_Rc_best['z'], label='LM-L2-MC-6-30', c='g', linestyle='dashed', linewidth='5')
#plt.scatter(my_X3D_k['k'], my_X3D_k['z'], label='mine')
#
plt.plot(Ali_X3D_k_best['k'], Ali_X3D_k_best['z'], linestyle = 'dashed',  linewidth='5', label='HAG', c='b') 
#plt.plot(Ali_X3D_k_best__['k'], Ali_X3D_k_best__['z'], linestyle = 'dashed',  linewidth='5', label='HAG', c='m')
plt.plot(Fabian_X3D_k_best['k'], Fabian_X3D_k_best['z'], label='LM-L2-MC-6-30', c='g', linestyle='dashed', linewidth='5')
#plt.plot(Fabian_X3D_k_best__['k'], Fabian_X3D_k_best__['z'], label='LM-L2-MC-6-30', c='m', linestyle='dotted', linewidth='5')
#plt.plot(me1_X3D_k['k'], me1_X3D_k['z'], linestyle = 'dashed',  linewidth='5', label='me1', c='y') 
#plt.plot(me1_X3D_k_Q2Q9['k'], me1_X3D_k_Q2Q9['z'], linestyle = 'dashed',  linewidth='5', label='me1', c='y') 
#plt.plot(X3D_k_best___['k'], X3D_k_best___['z'], label='check test new', c='m', linestyle='dashed', linewidth='5') # <--- strange!!! 
#plt.plot(me1_X3D_k_ABC['k'], me1_X3D_k_ABC['z'], label='my ABC', c='m', linestyle='dashed', linewidth='5')
#
plt.title('Wall-normal profiles of turbulence kinetic energy on centerline at x/d = 3 of NLEVM case')
plt.xlabel('k/u_f^2 [-]')
plt.xlabel(r'$k$ / $\bar{u}^2_{f}}$ [-]')
plt.ylabel("$z/d$ [-]")
#
plt.grid()
plt.legend()
plt.savefig('SC_TKE.png')
plt.show()
plt.close()
